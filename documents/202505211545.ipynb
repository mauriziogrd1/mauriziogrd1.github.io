# %%
from datetime import datetime
from IPython.display import display, Markdown, Latex

now = datetime.now()

day = now.weekday()
time = now.strftime("%H")

day = int(day)
time = int(time)

if day == 0:
  if time < 4:
    display(Markdown('[society for industrial and applied mathematics](https://www.siam.org/)'))
  if time < 8:
    if time > 4:
      display(Markdown('[università di torino, matematica](https://www.dipmatematica.unito.it/do/home.pl)'))
  if time < 12:
    if time > 8:
      display(Markdown('[oxford, matematica](https://www.maths.ox.ac.uk/)'))
  if time < 16:
    if time > 12:
      display(Markdown('[università federico ii, matematica](https://www.matematica.unina.it/)'))
  if time < 20:
    if time > 16:
      display(Markdown('[università sapienza, matematica](https://www.mat.uniroma1.it/)'))
  if time < 24:
    if time > 20:
      display(Markdown('[epfl, matematica](https://www.epfl.ch/schools/sb/research/math/)'))
if day == 1:
  if time < 4:
    display(Markdown('[moscow mathematical society](https://mms.mathnet.ru/)'))
  if time < 8:
    if time > 4:
      display(Markdown('[berkeley, matematica](https://math.berkeley.edu/home)'))
  if time < 12:
    if time > 8:
      display(Markdown('[matematicamente forum](https://forum.skuola.net/matematicamente)'))
  if time < 16:
    if time > 12:
      display(Markdown('[imperial, matematica](https://www.imperial.ac.uk/mathematics/)'))
  if time < 20:
    if time > 16:
      display(Markdown('[chinese mathematical society](http://www.cms.org.cn/)'))
  if time < 24:
    if time > 20:
      display(Markdown('[american mathematical society](https://www.ams.org/)'))
if day == 2:
  if time < 4:
    display(Markdown('[università di milano, matematica](https://matematica.unimi.it/)'))
  if time < 8:
    if time > 4:
      display(Markdown('[università di bologna, matematica](https://matematica.unibo.it/it)'))
  if time < 12:
    if time > 8:
      display(Markdown('[unione matematica italiana](https://umi.dm.unibo.it/)'))
  if time < 16:
    if time > 12:
      display(Markdown('[london mathematical society](https://www.lms.ac.uk/)'))
  if time < 20:
    if time > 16:
      display(Markdown('[politecnico di milano, matematica](https://www.mate.polimi.it/)'))
  if time < 24:
    if time > 20:
      display(Markdown('[mathematical association of america](https://maa.org/)'))
if day == 3:
  if time < 4:
    display(Markdown('[mit, matematica](https://math.mit.edu/)'))
  if time < 8:
    if time > 4:
      display(Markdown('[max planck institute for mathematics](https://www.mpim-bonn.mpg.de/)'))
  if time < 12:
    if time > 8:
      display(Markdown('[clay mathematics institute](https://www.claymath.org/)'))
  if time < 16:
    if time > 12:
      display(Markdown('[american statistical association](https://www.amstat.org/)'))
  if time < 20:
    if time > 16:
      display(Markdown('[università di pisa, matematica](https://www.dm.unipi.it/)'))
  if time < 24:
    if time > 20:
      display(Markdown('[simons foundation](https://www.simonsfoundation.org/)'))
if day == 4:
  if time < 4:
    display(Markdown('[ucl, matematica](https://www.ucl.ac.uk/maths/)'))
  if time < 8:
    if time > 4:
      display(Markdown('[università di padova, matematica](https://www.math.unipd.it/)'))
  if time < 12:
    if time > 8:
      display(Markdown('[caltech, matematica](https://pma.caltech.edu/research-and-academics/mathematics)'))
  if time < 16:
    if time > 12:
      display(Markdown('[politecnico di torino, matematica](https://www.disma.polito.it/)'))
  if time < 20:
    if time > 16:
      display(Markdown('[università di trento, matematica](https://www.maths.unitn.it/)'))
  if time < 24:
    if time > 20:
      display(Markdown('[cambridge, matematica](https://www.maths.cam.ac.uk/)'))
if day == 5:
  if time < 4:
    display(Markdown('[università bocconi, matematica](https://matematica.unibocconi.eu/)'))
  if time < 8:
    if time > 4:
      display(Markdown('[international statistical institute](https://isi-web.org/)'))
  if time < 12:
    if time > 8:
      display(Markdown('[institute for computational and experimental research in mathematics](https://icerm.brown.edu/)'))
  if time < 16:
    if time > 12:
      display(Markdown('[stanford, matematica](https://mathematics.stanford.edu/)'))
  if time < 20:
    if time > 16:
      display(Markdown('[olimpiadi della matematica](https://olimpiadi.dm.unibo.it/)'))
  if time < 24:
    if time > 20:
      display(Markdown('[societatea de stiinte matematice din romania](https://ssmr.ro/)'))
if day == 6:
  if time < 4:
    display(Markdown('[institut des hautes études scientifiques](https://www.ihes.fr/)'))
  if time < 8:
    if time > 4:
      display(Markdown('[institute for advanced study](https://www.ias.edu/)'))
  if time < 12:
    if time > 8:
      display(Markdown('[international mathematical union](https://www.mathunion.org/)'))
  if time < 16:
    if time > 12:
      display(Markdown('[eth, matematica](https://math.ethz.ch/)'))
  if time < 20:
    if time > 16:
      display(Markdown('[harvard, matematica](https://www.math.harvard.edu/)'))
  if time < 24:
    if time > 20:
      display(Markdown('[european mathematical society](https://euromathsoc.org/)'))
# Out:
# [london mathematical society](https://www.lms.ac.uk/)
